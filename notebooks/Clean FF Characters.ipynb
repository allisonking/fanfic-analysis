# %%
import pandas as pd

file = '../data/char_freq_ff.csv'

df = pd.read_csv(file)

# %%
df.head()
# Out:
#           name   percent
# 0     Harry P.  0.259269
# 1  Hermione G.  0.217112
# 2     Draco M.  0.188636
# 3   Severus S.  0.086407
# 4     James P.  0.081725

# %%
mapping = {}
for name in df['name']:
    mapping[name] = name

# %%
mapping['A. Sinistra'] = 'Aurora Sinistra'
mapping['Aberforth D.'] = 'Aberforth Dumbledore'
mapping['Abraxas M.'] = 'Abraxas Malfoy'
mapping['Albus D.'] = 'Albus Dumbledore'
mapping['Albus S. P.'] = 'Albus Severus Potter'
mapping['Alecto C.'] = 'Alecto Carrow'
mapping['Alice L.'] = 'Alice Longbottom'
mapping['Alicia S.'] = 'Alicia Spinnet'
mapping['Alphard B.'] = 'Alphard Black'
mapping['Amelia B.'] = 'Amelia Bones'
mapping['Amycus C.'] = 'Amycus Carrow'
mapping['Andromeda T.'] = 'Andromeda Tonks'
mapping['Angelina J.'] = 'Angelina Johnson'
mapping['Anthony G.'] = 'Anthony Goldstein'
mapping['Antonin D.'] = 'Antonin Dolohov'
mapping['Arabella F.'] = 'Arabella Figg'
mapping['Argus F.'] = 'Argus Filch'
mapping['Ariana D.'] = 'Ariana Dumbledore'
mapping['Arthur W.'] = 'Arthur Weasley'
mapping['Astoria G.'] = 'Astoria Greengrass'
mapping['Audrey W.'] = 'Audrey Weasley'
mapping['Augusta L.'] = 'Augusta Longbottom'
mapping['Barty C. Jr.'] = 'Barty Crouch Jr.'
mapping['Barty C. Sr.'] = 'Barty Crouch Sr.'
mapping['Bellatrix L.'] = 'Bellatrix Lestrange'
mapping['Benjy F.'] = 'Benjy Fenwick'
mapping['Bill W.'] = 'Bill Weasley'
mapping['Blaise Z.'] = 'Blaise Zabini'
mapping['C. Binns'] = 'Professor Binns'
mapping['C. Fudge'] = 'Cornelius Fudge'
mapping['Cedrella B.'] = 'Cedrella Weasley Black'
mapping['Cedric D.'] = 'Cedric Diggory'
mapping['Charity B.'] = 'Charity Burbage'
mapping['Charlie W.'] = 'Charlie Weasley'
mapping['Charlus P.'] = 'Charlus Potter'
mapping['Cho C.'] = 'Cho Chang'
mapping['Colin C.'] = 'Colin Creevey'
mapping['Cormac M.'] = 'Cormac McLaggen'
mapping['Cygnus B.'] = 'Cygnus Black'
mapping['Daphne G.'] = 'Daphne Greengrass'
mapping['Dean T.'] = 'Dean Thomas'
mapping['Demelza R.'] = 'Demelza Robins'
mapping['Dennis C.'] = 'Dennis Creevey'
mapping['Dolores U.'] = 'Dolores Umbridge'
mapping['Dominique W.'] = 'Dominique Weasley'
mapping['Dorcas M.'] = 'Dorcas Meadowes'
mapping['Dorea Black/Potter'] = 'Dorea Black Potter'
mapping['Dr. Granger'] = 'Mr. Granger'
mapping['Draco M.'] = 'Draco Malfoy'
mapping['Druella B.'] = 'Druella Black'
mapping['Dudley D.'] = 'Dudley Dursley'
mapping['Eileen P.'] = 'Eileen Prince'
mapping['Eloise M.'] = 'Eloise Midgen'
mapping['Emmeline V.'] = 'Emmeline Vance'
mapping['Ernie M.'] = 'Ernie Macmillan'
mapping['Evan R.'] = 'Evan Rosier'
mapping['F. Flitwick'] = 'Filius Flitwick'
mapping['Fabian P.'] = 'Fabian Prewett'
mapping['Fay D.'] = 'Fay Dunbar'
mapping['Fenrir G.'] = 'Fenrir Greyback'
mapping['Fleur D.'] = 'Fleur Delacour'
mapping['Frank L.'] = 'Frank Longbottom'
mapping['Fred W.'] = 'Fred Weasley'
mapping['Fred W. II'] = 'Fred Weasley II'
mapping['G. Montague'] = 'Montague'
mapping['G. Ollivander'] = 'Mr. Ollivander'
mapping['Gabrielle D.'] = 'Gabrielle Delacour'
mapping['Gellert G.'] = 'Gellert Grindelwald'
mapping['George W.'] = 'George Weasley'
mapping['Gideon P.'] = 'Gideon Prewett'
mapping['Gilderoy L.'] = 'Gilderoy Lockhart'
mapping['Ginny W.'] = 'Ginny Weasley'
mapping['Godric G.'] = 'Godric Gryffindor'
mapping['Gregory G.'] = 'Gregory Goyle'
mapping['Hannah A.'] = 'Hannah Abbott'
mapping['Harry P.'] = 'Harry Potter'
mapping['Helena R.'] = 'Helena Ravenclaw'
mapping['Helga H.'] = 'Helga Hufflepuff'
mapping['Hermione G.'] = 'Hermione Granger'
mapping['Hestia J.'] = 'Hestia Jones'
mapping['Horace S.'] = 'Horace Slughorn'
mapping['Hugo W.'] = 'Hugo Weasley'
mapping['I. Karkaroff'] = 'Igor Karkaroff'
mapping['I. Pince'] = 'Madam Pince'
mapping['Ignotus P.'] = 'Ignotus Peverell'
mapping['James P.'] = 'James Potter'
mapping['James S. P.'] = 'James Sirius Potter'
mapping['Jimmy P.'] = 'Jimmy Peakes'
mapping['Justin F.'] = 'Justin Finch-Fletchley'
mapping['Katie B.'] = 'Katie Bell'
mapping['Kingsley S.'] = 'Kingsley Shacklebolt'
mapping['Lavender B.'] = 'Lavender Brown'
mapping['Lee J.'] = 'Lee Jordan'
mapping['Lily Evans P.'] = 'Lily Potter'
mapping['Lily Luna P.'] = 'Lily Luna Potter'
mapping['Lisa T.'] = 'Lisa Turpin'
mapping['Lorcan S.'] = 'Lorcan Scamander'
mapping['Louis W.'] = 'Louis Weasley'
mapping['Lucius M.'] = 'Lucius Malfoy'
mapping['Lucy W.'] = 'Lucy Weasley'
mapping['Luna L.'] = 'Luna Lovegood'
mapping['Lyall L.'] = 'Lyall Lupin'
mapping['Lysander S.'] = 'Lysander Scamander'
mapping['Marcus F.'] = 'Marcus Flint'
mapping['Theodore N.'] = 'Theodore Nott'
mapping['Tobias S.'] = 'Tobias Snape'
mapping['Tom R. Jr.'] = 'Tom Riddle'
mapping['Tom R. Sr.'] = 'Tom Riddle Sr.'
mapping['Tracey D.'] = 'Tracey Davis'
mapping['Vernon D.'] = 'Vernon Dursley'
mapping['Victoire W.'] = 'Victoire Weasley'
mapping['Viktor K.'] = 'Viktor Krum'
mapping['Vincent C.'] = 'Vincent Crabbe'
mapping['Walburga B.'] = 'Walburga Black'
mapping['Xenophilius L.'] = 'Xenophilius Lovegood'
mapping['Zacharias S.'] = 'Zacharias Smith'
mapping['Adrian P.'] = 'Adrian Pucey'
mapping['Alastor M.'] = 'Alastor Moody'

# %%
mapping
# Out:
# {'A. Sinistra': 'Aurora Sinistra',
#  'Aberforth D.': 'Aberforth Dumbledore',
#  'Abraxas M.': 'Abraxas Malfoy',
#  'Adrian P.': 'Adrian Pucey',
#  'Alastor M.': 'Alastor Moody',
#  'Albus D.': 'Albus Dumbledore',
#  'Albus S. P.': 'Albus Severus Potter',
#  'Alecto C.': 'Alecto Carrow',
#  'Alice L.': 'Alice Longbottom',
#  'Alicia S.': 'Alicia Spinnet',
#  'Alphard B.': 'Alphard Black',
#  'Amelia B.': 'Amelia Bones',
#  'Amycus C.': 'Amycus Carrow',
#  'Andromeda T.': 'Andromeda Tonks',
#  'Angelina J.': 'Angelina Johnson',
#  'Anthony G.': 'Anthony Goldstein',
#  'Antonin D.': 'Antonin Dolohov',
#  'Arabella F.': 'Arabella Figg',
#  'Argus F.': 'Argus Filch',
#  'Ariana D.': 'Ariana Dumbledore',
#  'Arthur W.': 'Arthur Weasley',
#  'Astoria G.': 'Astoria Greengrass',
#  'Audrey W.': 'Audrey Weasley',
#  'Augusta L.': 'Augusta Longbottom',
#  'Barty C. Jr.': 'Barty Crouch Jr.',
#  'Barty C. Sr.': 'Barty Crouch Sr.',
#  'Basilisk': 'Basilisk',
# ...

# %%
len(mapping)
# Out:
# 198

# %%
df['name'] = df['name'].apply(lambda name: mapping[name])

# %%
df.columns=['name','fanfiction_percentage']

# %%
df
# Out:
#                        name  fanfiction_percentage
# 0              Harry Potter               0.259269
# 1          Hermione Granger               0.217112
# 2              Draco Malfoy               0.188636
# 3             Severus Snape               0.086407
# 4              James Potter               0.081725
# 5              Sirius Black               0.081025
# 6               Lily Potter               0.079643
# 7             Ginny Weasley               0.076098
# 8               Remus Lupin               0.067848
# 9               Ron Weasley               0.064901
# 10                       OC               0.056003
# 11                Voldemort               0.033871
# 12          Scorpius Malfoy               0.023569
# 13           George Weasley               0.020380
# 14            Luna Lovegood               0.020023
# 15             Fred Weasley               0.018278
# 16         Albus Dumbledore               0.017697
# ...

# %%
df.to_csv('../data/char_freq_ff_mapped.csv', index=False)
